# %% [markdown]
# # Test: Geospatial validation and mapping
#
# [Run in browser](https://muzammilafroz.github.io/applied-economics-data-learning-lab/lab/index.html?path=tests/02_geospatial_test.ipynb) | [Open in Colab](https://colab.research.google.com/github/muzammilafroz/applied-economics-data-learning-lab/blob/main/notebooks/tests/02_geospatial_test.ipynb) | [Course home](https://muzammilafroz.github.io/applied-economics-data-learning-lab/)
#
# > This independent learning resource uses fictional, synthetic data. It is not an official assessment or credential.

# %% [markdown]
# ## Instructions
#
# Run the setup cells, then write your own code in each blank answer cell. Keep every named answer variable because the final cell uses those names to create copyable JSON.
#
# The test is formative. The website requires 80 percent to pass, allows unlimited attempts, and reveals full explanations after a pass or after the second completed attempt. Browser answers and progress remain in local storage. Client-side answer keys are inspectable, so this is not secure certification.

# %%
from __future__ import annotations

import os
import sys
import types
from urllib.request import urlopen

if sys.platform == "emscripten":
    import piplite
    await piplite.install("pyodide-http")
    import pyodide_http
    pyodide_http.patch_all()

RAW_CODE_ROOT = "https://raw.githubusercontent.com/muzammilafroz/applied-economics-data-learning-lab/v1.0.0/learning_lab"
if sys.platform == "emscripten":
    from js import window
    if window.location.hostname in {"127.0.0.1", "localhost"}:
        RAW_CODE_ROOT = f"{window.location.origin}/learning_lab"
        os.environ["LEARNING_LAB_DATA_BASE"] = f"{window.location.origin}/data/teaching"

def load_public_module(module_name):
    """Import locally, or fetch the small public helper when running in Colab/Lite."""
    try:
        return __import__(f"learning_lab.{module_name}", fromlist=[module_name])
    except ModuleNotFoundError:
        location = f"{RAW_CODE_ROOT}/{module_name}.py"
        source = urlopen(location).read().decode("utf-8")
        module = types.ModuleType(f"learning_lab.{module_name}")
        exec(compile(source, location, "exec"), module.__dict__)
        return module

lab_io = load_public_module("io")
get_data_url = lab_io.get_data_url
read_teaching_csv = lab_io.read_teaching_csv
read_teaching_geojson = lab_io.read_teaching_geojson

print("Runtime:", sys.platform)
print("Data reference:", os.getenv("LEARNING_LAB_DATA_REF", "v1.0.0"))

# %%
import geopandas as gpd
if sys.platform == "emscripten":
    await piplite.install("mapclassify")
import mapclassify
import pandas as pd

districts = read_teaching_geojson()
production = read_teaching_csv("district_production.csv")
points = read_teaching_csv("survey_points.csv")
print("Geospatial teaching data loaded.")

# %% [markdown]
# ## Question 1
#
# Question ID: `m2_q01`
#
# How many district polygons are in the GeoJSON?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m2_polygon_count = None
m2_polygon_count

# %% [markdown]
# ## Question 2
#
# Question ID: `m2_q02`
#
# What coordinate reference system is assigned to the district GeoDataFrame?

# %%
# TODO: write your code above the assignment.
# Assign a text answer. Capitalization and surrounding spaces are ignored by the web form.
m2_crs = None
m2_crs

# %% [markdown]
# ## Question 3
#
# Question ID: `m2_q03`
#
# How many point rows belong to a repeated longitude-latitude pair, counting both originals and repeats?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m2_duplicated_rows = None
m2_duplicated_rows

# %% [markdown]
# ## Question 4
#
# Question ID: `m2_q04`
#
# How many distinct longitude-latitude pairs are repeated?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m2_duplicated_pairs = None
m2_duplicated_pairs

# %% [markdown]
# ## Question 5
#
# Question ID: `m2_q05`
#
# How many points belong to group D?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m2_group_d_count = None
m2_group_d_count

# %% [markdown]
# ## Question 6
#
# Question ID: `m2_q06`
#
# Which field should join production to district geometry?

# %%
# TODO: write your code above the assignment.
# Assign a text answer. Capitalization and surrounding spaces are ignored by the web form.
m2_join_key = None
m2_join_key

# %% [markdown]
# ## Question 7
#
# Question ID: `m2_q07`
#
# Which classification method is used for the skewed production map?
#
# - `fisher_jenks`: Fisher-Jenks
# - `quantiles`: Quantiles
# - `equal_interval`: Equal intervals
# - `manual`: Unvalidated manual breaks

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m2_classifier = None
m2_classifier

# %% [markdown]
# ## Question 8
#
# Question ID: `m2_q08`
#
# Where should a large legend be placed when it would cover district polygons?
#
# - `outside_reserved_space`: In reserved space outside the map
# - `over_data`: On top of the polygons
# - `remove`: Remove the legend
# - `tiny`: Shrink it until unreadable

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m2_legend_strategy = None
m2_legend_strategy

# %% [markdown]
# ## Create your answer bundle
#
# Run the next cell after filling every answer variable. Copy the printed JSON, open the [local test form](https://muzammilafroz.github.io/applied-economics-data-learning-lab/tests/?module=module-02), and use **Paste notebook bundle**. This cell does not grade or transmit your work.

# %%
import json

def json_ready(value):
    if hasattr(value, 'item'):
        return value.item()
    if isinstance(value, set):
        return sorted(value)
    return value

answer_bundle = {
    'schema_version': 1,
    'module_id': 'module-02',
    'answers': {
        'm2_q01': json_ready(m2_polygon_count),
        'm2_q02': json_ready(m2_crs),
        'm2_q03': json_ready(m2_duplicated_rows),
        'm2_q04': json_ready(m2_duplicated_pairs),
        'm2_q05': json_ready(m2_group_d_count),
        'm2_q06': json_ready(m2_join_key),
        'm2_q07': json_ready(m2_classifier),
        'm2_q08': json_ready(m2_legend_strategy),
    },
}
print(json.dumps(answer_bundle, indent=2, sort_keys=True))
