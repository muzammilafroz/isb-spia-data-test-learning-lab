# %% [markdown]
# # Test: Regression, fixed effects, and credibility
#
# [Run in browser](https://muzammilafroz.github.io/applied-economics-data-learning-lab/lab/index.html?path=tests/04_regression_test.ipynb) | [Open in Colab](https://colab.research.google.com/github/muzammilafroz/applied-economics-data-learning-lab/blob/main/notebooks/tests/04_regression_test.ipynb) | [Course home](https://muzammilafroz.github.io/applied-economics-data-learning-lab/)
#
# > This independent learning resource uses fictional, synthetic data. It is not an official assessment or credential.

# %% [markdown]
# ## Instructions
#
# Run the setup cells, then write your own code in each blank answer cell. Keep every named answer variable because the final cell uses those names to create copyable JSON.
#
# The test is formative. The website requires 80 percent to pass, allows unlimited attempts, and reveals full explanations after a pass or after the second completed attempt. Browser answers and progress remain in local storage. Client-side answer keys are inspectable, so this is not secure certification.

# %%
from __future__ import annotations

import os
import sys
import types
from urllib.request import urlopen

if sys.platform == "emscripten":
    import piplite
    await piplite.install("pyodide-http")
    import pyodide_http
    pyodide_http.patch_all()

RAW_CODE_ROOT = "https://raw.githubusercontent.com/muzammilafroz/applied-economics-data-learning-lab/v1.0.1/learning_lab"
if sys.platform == "emscripten":
    from js import window
    if window.location.hostname in {"127.0.0.1", "localhost"}:
        RAW_CODE_ROOT = f"{window.location.origin}/learning_lab"
        os.environ["LEARNING_LAB_DATA_BASE"] = f"{window.location.origin}/data/teaching"

def load_public_module(module_name):
    """Import locally, or fetch the small public helper when running in Colab/Lite."""
    try:
        return __import__(f"learning_lab.{module_name}", fromlist=[module_name])
    except ModuleNotFoundError:
        location = f"{RAW_CODE_ROOT}/{module_name}.py"
        source = urlopen(location).read().decode("utf-8")
        module = types.ModuleType(f"learning_lab.{module_name}")
        exec(compile(source, location, "exec"), module.__dict__)
        return module

lab_io = load_public_module("io")
get_data_url = lab_io.get_data_url
read_teaching_csv = lab_io.read_teaching_csv
read_teaching_geojson = lab_io.read_teaching_geojson

print("Runtime:", sys.platform)
print("Data reference:", os.getenv("LEARNING_LAB_DATA_REF", "v1.0.1"))

# %%
import numpy as np
import pandas as pd
import patsy
import statsmodels.formula.api as smf

analysis = read_teaching_csv("synthetic_analysis_clean.csv", dtype={"hhid": "string"})
print("Regression teaching data loaded.")

# %% [markdown]
# ## Question 1
#
# Question ID: `m4_q01`
#
# How many observations are in the pooled clean file before model-specific missing-value deletion?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m4_analysis_rows = None
m4_analysis_rows

# %% [markdown]
# ## Question 2
#
# Question ID: `m4_q02`
#
# How many survey waves are represented?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m4_wave_count = None
m4_wave_count

# %% [markdown]
# ## Question 3
#
# Question ID: `m4_q03`
#
# How many observed country-year pairs are represented?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m4_country_year_pairs = None
m4_country_year_pairs

# %% [markdown]
# ## Question 4
#
# Question ID: `m4_q04`
#
# Which heteroskedasticity-consistent covariance estimator is used when design fields are unavailable?
#
# - `HC1`: HC1
# - `nonrobust`: Nonrobust only
# - `cluster_psu`: Cluster by an unavailable PSU
# - `bootstrap_claim`: Claim design consistency without fields

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m4_covariance = None
m4_covariance

# %% [markdown]
# ## Question 5
#
# Question ID: `m4_q05`
#
# Which word best describes the estimated wealth-malaria relationship in this observational exercise?
#
# - `association`: Association
# - `causal_effect`: Causal effect
# - `treatment_effect`: Randomized treatment effect
# - `proof`: Proof

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m4_claim_language = None
m4_claim_language

# %% [markdown]
# ## Question 6
#
# Question ID: `m4_q06`
#
# Fit the documented adjusted model. What is the wealth_index coefficient?

# %%
# TODO: write your code above the assignment.
# Assign a numeric value. The web form uses the tolerance stated in its feedback.
m4_adjusted_wealth_coefficient = None
m4_adjusted_wealth_coefficient

# %% [markdown]
# ## Question 7
#
# Question ID: `m4_q07`
#
# Is the adjusted wealth coefficient positive or negative?

# %%
# TODO: write your code above the assignment.
# Assign a text answer. Capitalization and surrounding spaces are ignored by the web form.
m4_coefficient_sign = None
m4_coefficient_sign

# %% [markdown]
# ## Question 8
#
# Question ID: `m4_q08`
#
# How many observations enter the adjusted model after formula-level missing-value deletion?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m4_common_sample = None
m4_common_sample

# %% [markdown]
# ## Create your answer bundle
#
# Run the next cell after filling every answer variable. Copy the printed JSON, open the [local test form](https://muzammilafroz.github.io/applied-economics-data-learning-lab/tests/?module=module-04), and use **Paste notebook bundle**. This cell does not grade or transmit your work.

# %%
import json

def json_ready(value):
    if hasattr(value, 'item'):
        return value.item()
    if isinstance(value, set):
        return sorted(value)
    return value

answer_bundle = {
    'schema_version': 1,
    'module_id': 'module-04',
    'answers': {
        'm4_q01': json_ready(m4_analysis_rows),
        'm4_q02': json_ready(m4_wave_count),
        'm4_q03': json_ready(m4_country_year_pairs),
        'm4_q04': json_ready(m4_covariance),
        'm4_q05': json_ready(m4_claim_language),
        'm4_q06': json_ready(m4_adjusted_wealth_coefficient),
        'm4_q07': json_ready(m4_coefficient_sign),
        'm4_q08': json_ready(m4_common_sample),
    },
}
print(json.dumps(answer_bundle, indent=2, sort_keys=True))
