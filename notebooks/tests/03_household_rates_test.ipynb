# %% [markdown]
# # Test: Household rates and reproducible cleaning
#
# [Run in browser](https://muzammilafroz.github.io/applied-economics-data-learning-lab/lab/index.html?path=tests/03_household_rates_test.ipynb) | [Open in Colab](https://colab.research.google.com/github/muzammilafroz/applied-economics-data-learning-lab/blob/main/notebooks/tests/03_household_rates_test.ipynb) | [Course home](https://muzammilafroz.github.io/applied-economics-data-learning-lab/)
#
# > This independent learning resource uses fictional, synthetic data. It is not an official assessment or credential.

# %% [markdown]
# ## Instructions
#
# Run the setup cells, then write your own code in each blank answer cell. Keep every named answer variable because the final cell uses those names to create copyable JSON.
#
# The test is formative. The website requires 80 percent to pass, allows unlimited attempts, and reveals full explanations after a pass or after the second completed attempt. Browser answers and progress remain in local storage. Client-side answer keys are inspectable, so this is not secure certification.

# %%
from __future__ import annotations

import os
import sys
import types
from urllib.request import urlopen

if sys.platform == "emscripten":
    import piplite
    await piplite.install("pyodide-http")
    import pyodide_http
    pyodide_http.patch_all()

RAW_CODE_ROOT = "https://raw.githubusercontent.com/muzammilafroz/applied-economics-data-learning-lab/v1.0.1/learning_lab"
if sys.platform == "emscripten":
    from js import window
    if window.location.hostname in {"127.0.0.1", "localhost"}:
        RAW_CODE_ROOT = f"{window.location.origin}/learning_lab"
        os.environ["LEARNING_LAB_DATA_BASE"] = f"{window.location.origin}/data/teaching"

def load_public_module(module_name):
    """Import locally, or fetch the small public helper when running in Colab/Lite."""
    try:
        return __import__(f"learning_lab.{module_name}", fromlist=[module_name])
    except ModuleNotFoundError:
        location = f"{RAW_CODE_ROOT}/{module_name}.py"
        source = urlopen(location).read().decode("utf-8")
        module = types.ModuleType(f"learning_lab.{module_name}")
        exec(compile(source, location, "exec"), module.__dict__)
        return module

lab_io = load_public_module("io")
get_data_url = lab_io.get_data_url
read_teaching_csv = lab_io.read_teaching_csv
read_teaching_geojson = lab_io.read_teaching_geojson

print("Runtime:", sys.platform)
print("Data reference:", os.getenv("LEARNING_LAB_DATA_REF", "v1.0.1"))

# %%
import numpy as np
import pandas as pd

transformations = load_public_module("transformations")
tests = read_teaching_csv("lumen_2018_test_results.csv", dtype={"hhid": "string"})
survey = read_teaching_csv("lumen_2018_survey.csv", dtype={"hhid": "string"})
analysis = read_teaching_csv("synthetic_analysis_clean.csv", dtype={"hhid": "string"})
print("Household teaching data loaded.")

# %% [markdown]
# ## Question 1
#
# Question ID: `m3_q01`
#
# How many test-result slots are present in the wide file?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m3_test_slots = None
m3_test_slots

# %% [markdown]
# ## Question 2
#
# Question ID: `m3_q02`
#
# How many household rows are in the test-result file?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m3_households = None
m3_households

# %% [markdown]
# ## Question 3
#
# Question ID: `m3_q03`
#
# How many households have no nonblank test result?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m3_zero_denominators = None
m3_zero_denominators

# %% [markdown]
# ## Question 4
#
# Question ID: `m3_q04`
#
# How many households have a defined positive rate?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m3_valid_rates = None
m3_valid_rates

# %% [markdown]
# ## Question 5
#
# Question ID: `m3_q05`
#
# What is the first household ID with a defined rate? Keep all eight positions.

# %%
# TODO: write your code above the assignment.
# Assign a text answer. Capitalization and surrounding spaces are ignored by the web form.
m3_first_valid_id = None
m3_first_valid_id

# %% [markdown]
# ## Question 6
#
# Question ID: `m3_q06`
#
# How many nonblank results are labelled inconclusive?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m3_other_outcomes = None
m3_other_outcomes

# %% [markdown]
# ## Question 7
#
# Question ID: `m3_q07`
#
# Which merge validation contract fits one survey row and one rate row per household ID?
#
# - `one_to_one`: one_to_one
# - `one_to_many`: one_to_many
# - `many_to_one`: many_to_one
# - `many_to_many`: many_to_many

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m3_merge_contract = None
m3_merge_contract

# %% [markdown]
# ## Question 8
#
# Question ID: `m3_q08`
#
# How many rows are in the pooled clean analysis file?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m3_clean_rows = None
m3_clean_rows

# %% [markdown]
# ## Question 9
#
# Question ID: `m3_q09`
#
# How many pooled households are classified as using a poor water source?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m3_poorwater_count = None
m3_poorwater_count

# %% [markdown]
# ## Question 10
#
# Question ID: `m3_q10`
#
# How should a zero-denominator household rate be represented?
#
# - `missing`: Missing
# - `zero`: Zero
# - `one`: One
# - `drop_raw_row`: Delete the raw household row

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m3_zero_rate_rule = None
m3_zero_rate_rule

# %% [markdown]
# ## Create your answer bundle
#
# Run the next cell after filling every answer variable. Copy the printed JSON, open the [local test form](https://muzammilafroz.github.io/applied-economics-data-learning-lab/tests/?module=module-03), and use **Paste notebook bundle**. This cell does not grade or transmit your work.

# %%
import json

def json_ready(value):
    if hasattr(value, 'item'):
        return value.item()
    if isinstance(value, set):
        return sorted(value)
    return value

answer_bundle = {
    'schema_version': 1,
    'module_id': 'module-03',
    'answers': {
        'm3_q01': json_ready(m3_test_slots),
        'm3_q02': json_ready(m3_households),
        'm3_q03': json_ready(m3_zero_denominators),
        'm3_q04': json_ready(m3_valid_rates),
        'm3_q05': json_ready(m3_first_valid_id),
        'm3_q06': json_ready(m3_other_outcomes),
        'm3_q07': json_ready(m3_merge_contract),
        'm3_q08': json_ready(m3_clean_rows),
        'm3_q09': json_ready(m3_poorwater_count),
        'm3_q10': json_ready(m3_zero_rate_rule),
    },
}
print(json.dumps(answer_bundle, indent=2, sort_keys=True))
