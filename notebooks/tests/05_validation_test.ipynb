# %% [markdown]
# # Test: Validation, reproducibility, and interview defense
#
# [Run in browser](https://muzammilafroz.github.io/isb-spia-data-test-learning-lab/lab/index.html?path=tests/05_validation_test.ipynb) | [Open in Colab](https://colab.research.google.com/github/muzammilafroz/isb-spia-data-test-learning-lab/blob/main/notebooks/tests/05_validation_test.ipynb) | [Course home](https://muzammilafroz.github.io/isb-spia-data-test-learning-lab/)
#
# > This independent learning resource uses fictional, synthetic data. It is not an official ISB or SPIA product or credential.

# %% [markdown]
# ## Instructions
#
# Run the setup cells, then write your own code in each blank answer cell. Keep every named answer variable because the final cell uses those names to create copyable JSON.
#
# The test is formative. The website requires 80 percent to pass, allows unlimited attempts, and reveals full explanations after a pass or after the second completed attempt. Browser answers and progress remain in local storage. Client-side answer keys are inspectable, so this is not secure certification.

# %%
from __future__ import annotations

import os
import sys
import types
from urllib.request import urlopen

if sys.platform == "emscripten":
    import piplite
    await piplite.install("pyodide-http")
    import pyodide_http
    pyodide_http.patch_all()

RAW_CODE_ROOT = "https://raw.githubusercontent.com/muzammilafroz/isb-spia-data-test-learning-lab/v1.0.0/learning_lab"
if sys.platform == "emscripten":
    from js import window
    if window.location.hostname in {"127.0.0.1", "localhost"}:
        RAW_CODE_ROOT = f"{window.location.origin}/learning_lab"
        os.environ["LEARNING_LAB_DATA_BASE"] = f"{window.location.origin}/data/teaching"

def load_public_module(module_name):
    """Import locally, or fetch the small public helper when running in Colab/Lite."""
    try:
        return __import__(f"learning_lab.{module_name}", fromlist=[module_name])
    except ModuleNotFoundError:
        location = f"{RAW_CODE_ROOT}/{module_name}.py"
        source = urlopen(location).read().decode("utf-8")
        module = types.ModuleType(f"learning_lab.{module_name}")
        exec(compile(source, location, "exec"), module.__dict__)
        return module

lab_io = load_public_module("io")
get_data_url = lab_io.get_data_url
read_teaching_csv = lab_io.read_teaching_csv
read_teaching_geojson = lab_io.read_teaching_geojson

print("Runtime:", sys.platform)
print("Data reference:", os.getenv("LEARNING_LAB_DATA_REF", "v1.0.0"))

# %%
import json
from pathlib import Path

def read_json_file(filename):
    location = get_data_url(filename)
    if str(location).startswith(("http://", "https://")):
        return json.loads(urlopen(location).read().decode("utf-8"))
    return json.loads(Path(location).read_text(encoding="utf-8"))

manifest = read_json_file("data_manifest.json")
expected = read_json_file("expected_outputs.json")
print("Validation metadata loaded.")

# %% [markdown]
# ## Question 1
#
# Question ID: `m5_q01`
#
# What is the value of synthetic_only in data_manifest.json?

# %%
# TODO: write your code above the assignment.
# Assign a text answer. Capitalization and surrounding spaces are ignored by the web form.
m5_synthetic_flag = None
m5_synthetic_flag

# %% [markdown]
# ## Question 2
#
# Question ID: `m5_q02`
#
# How many generated teaching files are recorded in the manifest?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m5_manifest_files = None
m5_manifest_files

# %% [markdown]
# ## Question 3
#
# Question ID: `m5_q03`
#
# Why execute a notebook from a fresh kernel?
#
# - `detect_hidden_state`: Detect hidden state and ordering dependencies
# - `change_answers`: Change inconvenient results
# - `skip_errors`: Skip cells that fail
# - `decorate`: Improve colors automatically

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m5_fresh_kernel_reason = None
m5_fresh_kernel_reason

# %% [markdown]
# ## Question 4
#
# Question ID: `m5_q04`
#
# What is the strongest check after saving a figure?
#
# - `open_exact_file`: Open and inspect the exact saved file
# - `exists_only`: Check only that a path exists
# - `trust_code`: Assume plotting code guarantees readability
# - `check_name`: Read only the filename

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m5_figure_check = None
m5_figure_check

# %% [markdown]
# ## Question 5
#
# Question ID: `m5_q05`
#
# What does a stored file hash help detect?
#
# - `byte_changes`: Unexpected byte changes
# - `causality`: Causal identification
# - `missing_weights`: Unavailable survey weights
# - `plot_taste`: Whether a color is attractive

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m5_hash_purpose = None
m5_hash_purpose

# %% [markdown]
# ## Question 6
#
# Question ID: `m5_q06`
#
# Which AI disclosure is defensible?
#
# - `specific_verified`: Describe assistance and independent verification
# - `deny`: Deny assistance that occurred
# - `delegate`: Claim AI is responsible for errors
# - `vague`: Give a vague statement with no verification

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m5_ai_disclosure = None
m5_ai_disclosure

# %% [markdown]
# ## Question 7
#
# Question ID: `m5_q07`
#
# What is the pooled four-wave dataset: a panel or a repeated cross-section?
#
# - `repeated_cross_section`: Repeated cross-section
# - `household_panel`: Household panel
# - `time_series`: Single time series
# - `experiment`: Randomized experiment

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m5_data_structure = None
m5_data_structure

# %% [markdown]
# ## Question 8
#
# Question ID: `m5_q08`
#
# What should come first when defending an analytical decision?
#
# - `purpose_and_constraint`: Purpose and data constraint
# - `package_name`: A package name without context
# - `large_claim`: The largest possible claim
# - `apology`: An apology before the evidence

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m5_interview_opening = None
m5_interview_opening

# %% [markdown]
# ## Create your answer bundle
#
# Run the next cell after filling every answer variable. Copy the printed JSON, open the [local test form](https://muzammilafroz.github.io/isb-spia-data-test-learning-lab/tests/?module=module-05), and use **Paste notebook bundle**. This cell does not grade or transmit your work.

# %%
import json

def json_ready(value):
    if hasattr(value, 'item'):
        return value.item()
    if isinstance(value, set):
        return sorted(value)
    return value

answer_bundle = {
    'schema_version': 1,
    'module_id': 'module-05',
    'answers': {
        'm5_q01': json_ready(m5_synthetic_flag),
        'm5_q02': json_ready(m5_manifest_files),
        'm5_q03': json_ready(m5_fresh_kernel_reason),
        'm5_q04': json_ready(m5_figure_check),
        'm5_q05': json_ready(m5_hash_purpose),
        'm5_q06': json_ready(m5_ai_disclosure),
        'm5_q07': json_ready(m5_data_structure),
        'm5_q08': json_ready(m5_interview_opening),
    },
}
print(json.dumps(answer_bundle, indent=2, sort_keys=True))
