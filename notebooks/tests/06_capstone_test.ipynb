# %% [markdown]
# # Integrated capstone
#
# [Run in browser](https://muzammilafroz.github.io/applied-economics-data-learning-lab/lab/index.html?path=tests/06_capstone_test.ipynb) | [Open in Colab](https://colab.research.google.com/github/muzammilafroz/applied-economics-data-learning-lab/blob/main/notebooks/tests/06_capstone_test.ipynb) | [Course home](https://muzammilafroz.github.io/applied-economics-data-learning-lab/)
#
# > This independent learning resource uses fictional, synthetic data. It is not an official assessment or credential.

# %% [markdown]
# ## Instructions
#
# Run the setup cells, then write your own code in each blank answer cell. Keep every named answer variable because the final cell uses those names to create copyable JSON.
#
# The test is formative. The website requires 80 percent to pass, allows unlimited attempts, and reveals full explanations after a pass or after the second completed attempt. Browser answers and progress remain in local storage. Client-side answer keys are inspectable, so this is not secure certification.

# %%
from __future__ import annotations

import os
import sys
import types
from urllib.request import urlopen

if sys.platform == "emscripten":
    import piplite
    await piplite.install("pyodide-http")
    import pyodide_http
    pyodide_http.patch_all()

RAW_CODE_ROOT = "https://raw.githubusercontent.com/muzammilafroz/applied-economics-data-learning-lab/v1.0.0/learning_lab"
if sys.platform == "emscripten":
    from js import window
    if window.location.hostname in {"127.0.0.1", "localhost"}:
        RAW_CODE_ROOT = f"{window.location.origin}/learning_lab"
        os.environ["LEARNING_LAB_DATA_BASE"] = f"{window.location.origin}/data/teaching"

def load_public_module(module_name):
    """Import locally, or fetch the small public helper when running in Colab/Lite."""
    try:
        return __import__(f"learning_lab.{module_name}", fromlist=[module_name])
    except ModuleNotFoundError:
        location = f"{RAW_CODE_ROOT}/{module_name}.py"
        source = urlopen(location).read().decode("utf-8")
        module = types.ModuleType(f"learning_lab.{module_name}")
        exec(compile(source, location, "exec"), module.__dict__)
        return module

lab_io = load_public_module("io")
get_data_url = lab_io.get_data_url
read_teaching_csv = lab_io.read_teaching_csv
read_teaching_geojson = lab_io.read_teaching_geojson

print("Runtime:", sys.platform)
print("Data reference:", os.getenv("LEARNING_LAB_DATA_REF", "v1.0.0"))

# %%
import json
from pathlib import Path

import numpy as np
import pandas as pd
import statsmodels.formula.api as smf

production = read_teaching_csv("district_production.csv")
points = read_teaching_csv("survey_points.csv")
tests = read_teaching_csv("lumen_2018_test_results.csv", dtype={"hhid": "string"})
analysis = read_teaching_csv("synthetic_analysis_clean.csv", dtype={"hhid": "string"})
print("Capstone data loaded.")

# %% [markdown]
# ## Question 1
#
# Question ID: `cap_q01`
#
# How many sampling-point rows are present?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
cap_point_count = None
cap_point_count

# %% [markdown]
# ## Question 2
#
# Question ID: `cap_q02`
#
# What is the largest district production value?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
cap_maximum_production = None
cap_maximum_production

# %% [markdown]
# ## Question 3
#
# Question ID: `cap_q03`
#
# Which district code d has that largest production value?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
cap_maximum_district_code = None
cap_maximum_district_code

# %% [markdown]
# ## Question 4
#
# Question ID: `cap_q04`
#
# How many Lumen 2018 households have a defined positive rate?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
cap_valid_rate_households = None
cap_valid_rate_households

# %% [markdown]
# ## Question 5
#
# Question ID: `cap_q05`
#
# How many observed test results are inconclusive?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
cap_inconclusive_results = None
cap_inconclusive_results

# %% [markdown]
# ## Question 6
#
# Question ID: `cap_q06`
#
# What is the positive rate for household 04000001?

# %%
# TODO: write your code above the assignment.
# Assign a numeric value. The web form uses the tolerance stated in its feedback.
cap_first_valid_rate = None
cap_first_valid_rate

# %% [markdown]
# ## Question 7
#
# Question ID: `cap_q07`
#
# How many household-wave rows are in the pooled clean file?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
cap_pooled_rows = None
cap_pooled_rows

# %% [markdown]
# ## Question 8
#
# Question ID: `cap_q08`
#
# What fraction of pooled households use a poor water source? Report a value from zero to one.

# %%
# TODO: write your code above the assignment.
# Assign a numeric value. The web form uses the tolerance stated in its feedback.
cap_poorwater_share = None
cap_poorwater_share

# %% [markdown]
# ## Question 9
#
# Question ID: `cap_q09`
#
# In positive_rate ~ wealth_index, what is the wealth_index coefficient?

# %%
# TODO: write your code above the assignment.
# Assign a numeric value. The web form uses the tolerance stated in its feedback.
cap_unadjusted_wealth_coefficient = None
cap_unadjusted_wealth_coefficient

# %% [markdown]
# ## Question 10
#
# Question ID: `cap_q10`
#
# Which fixed effect directly represents the four observed survey waves without redundant country and year dummy sets?
#
# - `survey_wave`: Survey-wave fixed effects
# - `household`: Household fixed effects for unrelated households
# - `country_plus_year`: Both full country and year sets despite rank redundancy
# - `none_claim`: No effects and no disclosure

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
cap_fixed_effect = None
cap_fixed_effect

# %% [markdown]
# ## Question 11
#
# Question ID: `cap_q11`
#
# Which phrase is appropriate for the regression result?
#
# - `negatively_associated`: Negatively associated
# - `caused_reduction`: Caused a reduction
# - `proved`: Proved the mechanism
# - `randomized`: Estimated a randomized effect

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
cap_result_language = None
cap_result_language

# %% [markdown]
# ## Question 12
#
# Question ID: `cap_q12`
#
# Select every survey-design field that is unavailable in this teaching setup and cannot be invented.
#
# - `weights`: Survey weights
# - `psu`: Primary sampling units
# - `strata`: Strata
# - `wealth`: The synthetic wealth index

# %%
# TODO: write your code above the assignment.
# Assign a list of selected choice values, for example: ['value_a', 'value_b']
cap_missing_design_fields = None
cap_missing_design_fields

# %% [markdown]
# ## Create your answer bundle
#
# Run the next cell after filling every answer variable. Copy the printed JSON, open the [local test form](https://muzammilafroz.github.io/applied-economics-data-learning-lab/tests/?module=capstone), and use **Paste notebook bundle**. This cell does not grade or transmit your work.

# %%
import json

def json_ready(value):
    if hasattr(value, 'item'):
        return value.item()
    if isinstance(value, set):
        return sorted(value)
    return value

answer_bundle = {
    'schema_version': 1,
    'module_id': 'capstone',
    'answers': {
        'cap_q01': json_ready(cap_point_count),
        'cap_q02': json_ready(cap_maximum_production),
        'cap_q03': json_ready(cap_maximum_district_code),
        'cap_q04': json_ready(cap_valid_rate_households),
        'cap_q05': json_ready(cap_inconclusive_results),
        'cap_q06': json_ready(cap_first_valid_rate),
        'cap_q07': json_ready(cap_pooled_rows),
        'cap_q08': json_ready(cap_poorwater_share),
        'cap_q09': json_ready(cap_unadjusted_wealth_coefficient),
        'cap_q10': json_ready(cap_fixed_effect),
        'cap_q11': json_ready(cap_result_language),
        'cap_q12': json_ready(cap_missing_design_fields),
    },
}
print(json.dumps(answer_bundle, indent=2, sort_keys=True))
