# %% [markdown]
# # Test: Python and pandas foundations
#
# [Run in browser](https://muzammilafroz.github.io/applied-economics-data-learning-lab/lab/index.html?path=tests/01_python_pandas_test.ipynb) | [Open in Colab](https://colab.research.google.com/github/muzammilafroz/applied-economics-data-learning-lab/blob/main/notebooks/tests/01_python_pandas_test.ipynb) | [Course home](https://muzammilafroz.github.io/applied-economics-data-learning-lab/)
#
# > This independent learning resource uses fictional, synthetic data. It is not an official assessment or credential.

# %% [markdown]
# ## Instructions
#
# Run the setup cells, then write your own code in each blank answer cell. Keep every named answer variable because the final cell uses those names to create copyable JSON.
#
# The test is formative. The website requires 80 percent to pass, allows unlimited attempts, and reveals full explanations after a pass or after the second completed attempt. Browser answers and progress remain in local storage. Client-side answer keys are inspectable, so this is not secure certification.

# %%
from __future__ import annotations

import os
import sys
import types
from urllib.request import urlopen

if sys.platform == "emscripten":
    import piplite
    await piplite.install("pyodide-http")
    import pyodide_http
    pyodide_http.patch_all()

RAW_CODE_ROOT = "https://raw.githubusercontent.com/muzammilafroz/applied-economics-data-learning-lab/v1.0.0/learning_lab"
if sys.platform == "emscripten":
    from js import window
    if window.location.hostname in {"127.0.0.1", "localhost"}:
        RAW_CODE_ROOT = f"{window.location.origin}/learning_lab"
        os.environ["LEARNING_LAB_DATA_BASE"] = f"{window.location.origin}/data/teaching"

def load_public_module(module_name):
    """Import locally, or fetch the small public helper when running in Colab/Lite."""
    try:
        return __import__(f"learning_lab.{module_name}", fromlist=[module_name])
    except ModuleNotFoundError:
        location = f"{RAW_CODE_ROOT}/{module_name}.py"
        source = urlopen(location).read().decode("utf-8")
        module = types.ModuleType(f"learning_lab.{module_name}")
        exec(compile(source, location, "exec"), module.__dict__)
        return module

lab_io = load_public_module("io")
get_data_url = lab_io.get_data_url
read_teaching_csv = lab_io.read_teaching_csv
read_teaching_geojson = lab_io.read_teaching_geojson

print("Runtime:", sys.platform)
print("Data reference:", os.getenv("LEARNING_LAB_DATA_REF", "v1.0.0"))

# %%
import pandas as pd

production = read_teaching_csv("district_production.csv")
points = read_teaching_csv("survey_points.csv")
districts = read_teaching_geojson()
print("Data loaded. Work from these three objects: production, points, districts.")

# %% [markdown]
# ## Question 1
#
# Question ID: `m1_q01`
#
# How many rows are in district_production.csv?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m1_district_rows = None
m1_district_rows

# %% [markdown]
# ## Question 2
#
# Question ID: `m1_q02`
#
# How many unique values are in the district code column d?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m1_unique_codes = None
m1_unique_codes

# %% [markdown]
# ## Question 3
#
# Question ID: `m1_q03`
#
# Which display name is deliberately used by two districts?

# %%
# TODO: write your code above the assignment.
# Assign a text answer. Capitalization and surrounding spaces are ignored by the web form.
m1_duplicated_name = None
m1_duplicated_name

# %% [markdown]
# ## Question 4
#
# Question ID: `m1_q04`
#
# Select every sampling group present in survey_points.csv.
#
# - `A`: A
# - `B`: B
# - `C`: C
# - `D`: D
# - `E`: E

# %%
# TODO: write your code above the assignment.
# Assign a list of selected choice values, for example: ['value_a', 'value_b']
m1_groups = None
m1_groups

# %% [markdown]
# ## Question 5
#
# Question ID: `m1_q05`
#
# How many sampling points belong to group A?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m1_group_a_count = None
m1_group_a_count

# %% [markdown]
# ## Question 6
#
# Question ID: `m1_q06`
#
# Which broad data type best describes the production column?
#
# - `integer`: Integer
# - `floating`: Floating point
# - `text`: Text
# - `boolean`: Boolean

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m1_production_kind = None
m1_production_kind

# %% [markdown]
# ## Question 7
#
# Question ID: `m1_q07`
#
# How many production values are missing?

# %%
# TODO: write your code above the assignment.
# Assign one whole-number answer.
m1_missing_production = None
m1_missing_production

# %% [markdown]
# ## Question 8
#
# Question ID: `m1_q08`
#
# Which pandas merge validation contract should be used when both tables have one row per district code?
#
# - `one_to_one`: one_to_one
# - `one_to_many`: one_to_many
# - `many_to_one`: many_to_one
# - `many_to_many`: many_to_many

# %%
# TODO: write your code above the assignment.
# Assign one choice value as a string.
m1_merge_contract = None
m1_merge_contract

# %% [markdown]
# ## Create your answer bundle
#
# Run the next cell after filling every answer variable. Copy the printed JSON, open the [local test form](https://muzammilafroz.github.io/applied-economics-data-learning-lab/tests/?module=module-01), and use **Paste notebook bundle**. This cell does not grade or transmit your work.

# %%
import json

def json_ready(value):
    if hasattr(value, 'item'):
        return value.item()
    if isinstance(value, set):
        return sorted(value)
    return value

answer_bundle = {
    'schema_version': 1,
    'module_id': 'module-01',
    'answers': {
        'm1_q01': json_ready(m1_district_rows),
        'm1_q02': json_ready(m1_unique_codes),
        'm1_q03': json_ready(m1_duplicated_name),
        'm1_q04': json_ready(m1_groups),
        'm1_q05': json_ready(m1_group_a_count),
        'm1_q06': json_ready(m1_production_kind),
        'm1_q07': json_ready(m1_missing_production),
        'm1_q08': json_ready(m1_merge_contract),
    },
}
print(json.dumps(answer_bundle, indent=2, sort_keys=True))
